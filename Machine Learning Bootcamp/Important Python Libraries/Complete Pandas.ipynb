# %% [markdown]
# Pandas library :
#
# Useful for data processing and analytics

# %% [raw]
# Pandas dataframe is a two-dimensional array with labeled rows and columns
#
# array vs dataframe :
# array : 2D columns and rows
# dataframe : labelled rows (axis) and columns

# %%
#importing pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# Creating a Pandas Dataframe

# %%
#importing dataset
from sklearn.datasets import load_boston

# %%
boston_dataset = load_boston()

# %%
type(boston_dataset)
# Out:
# sklearn.utils.Bunch

# %%
print(boston_dataset)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
boston_df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
credit_card = pd.read_csv('creditcard.csv')

# %%
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card.shape
# Out:
# (284807, 31)

# %%
#pd.read_excel()

# %% [markdown]
# Exporting to csv/Excel

# %%
boston_df.to_csv('boston_csv.csv')

# %% [markdown]
# Creating a dataset with Random values

# %%
random_df = pd.DataFrame(np.random.rand(100).reshape(10,10))

# %%
random_df.shape
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.622078  0.078891  0.616393  0.868032  0.957323  0.349775  0.140332
# 1  0.354116  0.580504  0.499834  0.119008  0.233270  0.376931  0.231151
# 2  0.722312  0.272817  0.474149  0.234899  0.149125  0.626059  0.015710
# 3  0.969717  0.665785  0.466470  0.515068  0.165359  0.661138  0.158626
# 4  0.631561  0.558348  0.835964  0.262727  0.934624  0.118539  0.177348
# 5  0.244541  0.517358  0.953105  0.501207  0.136063  0.019263  0.776540
# 6  0.621825  0.017220  0.534603  0.051044  0.850404  0.419984  0.255134
# 7  0.689268  0.472560  0.935754  0.494414  0.021637  0.645258  0.549157
# 8  0.487652  0.140994  0.832664  0.131932  0.501314  0.462430  0.779311
# 9  0.513775  0.429320  0.546720  0.800452  0.674689  0.824867  0.095593
#
#           7         8         9
# 0  0.077043  0.924812  0.230667
# 1  0.979518  0.876300  0.491642
# 2  0.896315  0.334136  0.445510
# 3  0.773222  0.995106  0.262048
# ...

# %%
random_df.shape
# Out:
# (10, 10)

# %% [markdown]
# Inspecting a Dataframe

# %%
#number of rows and columns
boston_df.shape
# Out:
# (506, 13)

# %%
#first 5 rows
boston_df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#last 5 rows
boston_df.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
#information about df
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
#number of missing values in each column
boston_df['CRIM'].fillna(0)
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
boston_df.duplicated().sum()
# Out:
# 0

# %%
#number of unique values in each column
boston_df.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# dtype: int64

# %%
#number of duplicates #enteries
boston_df.duplicated().sum()
# Out:
# 0

# %%
#number of duplicates #by column
boston_df['CRIM'].duplicated().sum()
# Out:
# 2

# %%
#value counts #usually used for cateogries like Gender, class, etc. 
credit_card['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
credit_card.groupby(by = 'Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#group by 
credit_card.groupby('Class')['Amount'].mean()
# Out:
# Class
# 0     88.291022
# 1    122.211321
# Name: Amount, dtype: float64

# %%
#fill null values 
boston_df['CRIM'].fillna('0', inplace = True)
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
credit_card['V7']
# Out:
# 0         0.239599
# 1        -0.078803
# 2         0.791461
# 3         0.237609
# 4         0.592941
#             ...
# 284802   -4.918215
# 284803    0.024330
# 284804   -0.296827
# 284805   -0.686180
# 284806    1.577006
# Name: V7, Length: 284807, dtype: float64

# %% [markdown]
# Statistical Measures

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#number of values
boston_df.count()
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# dtype: int64

# %% [markdown]
# Manipulating a DataFrame

# %%
#add a column
boston_df['Test_column'] = pd.Series(range(506))

# %%
boston_df['Price'] = boston_dataset.target

# %%
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Test_column  Price
# 0       15.3  396.90   4.98            0   24.0
# ...

# %%
boston_df.drop('Test_column', axis = 1) #drop a column

#axis - 1 >column 
#axis - 0 > row
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
boston_df.drop(index =0, axis = 0) #drop a row
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 1    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# 5    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price  Test_column
# 1       17.8  396.90   9.14   21.6            1
# ...

# %% [markdown]
# Indexing and Slicing

# %%
#locating a row using an index value
boston_df.iloc[3:6]
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 3  0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7
# 4  0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7
# 5  0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0     18.7
#
#         B  LSTAT  Price  Test_column
# 3  394.63   2.94   33.4            3
# 4  396.90   5.33   36.2            4
# 5  394.12   5.21   28.7            5

# %%
boston_df.iloc[:,0] #first column
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
boston_df.iloc[:,-1] #last column
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 501    501
# 502    502
# 503    503
# 504    504
# 505    505
# Name: Test_column, Length: 506, dtype: int64

# %%
#locating a row using an index and slicing
boston_df.iloc[3:6, 2:8]

# %%
#extracting a column
boston_df['NOX'].iloc[2:8]
# Out:
# 2    0.469
# 3    0.458
# 4    0.458
# 5    0.458
# 6    0.524
# 7    0.524
# Name: NOX, dtype: float64

# %% [markdown]
# Positive Correlation
# Negative Correlation

# %% [raw]
# Positive correlation - If one column increases another column increases (For eg. Number of rooms and House prices)
# Negative Correlation - If one column incraeses value of another column decreases (For eg. Crime rate and House prices)

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price  Test_column
# 0     15.3  396.90   4.98   24.0            0
# 1     17.8  396.90   9.14   21.6            1
# 2     17.8  392.83   4.03   34.7            2
# 3     18.7  394.63   2.94   33.4            3
# 4     18.7  396.90   5.33   36.2            4

# %%
boston_df.corr()
# Out:
#                  CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM         1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN          -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS        0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS        -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX          0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM          -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE          0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS         -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD          0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX          0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO      0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B           -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# ...

# %%
credit_card['V1'].duplicated().sum()
# Out:
# 9144

# %%
credit_card.loc[:,'V3':]
# Out:
#               V3        V4        V5        V6        V7        V8        V9  \
# 0       2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787
# 1       0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425
# 2       1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654
# 3       1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024
# 4       1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -9.834783 -2.066656 -5.364473 -2.606837 -4.918215  7.305334  1.914428
# 284803  2.035030 -0.738589  0.868229  1.058415  0.024330  0.294869  0.584800
# 284804 -3.249640 -0.557828  2.630515  3.031260 -0.296827  0.708417  0.432454
# 284805  0.702510  0.689799 -0.377961  0.623708 -0.686180  0.679145  0.392087
# 284806  0.703337 -0.506271 -0.012546 -0.649617  1.577006 -0.414650  0.486180
#
# ...

# %%
credit_card.iloc[:, 3:]
# Out:
#               V3        V4        V5        V6        V7        V8        V9  \
# 0       2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787
# 1       0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425
# 2       1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654
# 3       1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024
# 4       1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -9.834783 -2.066656 -5.364473 -2.606837 -4.918215  7.305334  1.914428
# 284803  2.035030 -0.738589  0.868229  1.058415  0.024330  0.294869  0.584800
# 284804 -3.249640 -0.557828  2.630515  3.031260 -0.296827  0.708417  0.432454
# 284805  0.702510  0.689799 -0.377961  0.623708 -0.686180  0.679145  0.392087
# 284806  0.703337 -0.506271 -0.012546 -0.649617  1.577006 -0.414650  0.486180
#
# ...
